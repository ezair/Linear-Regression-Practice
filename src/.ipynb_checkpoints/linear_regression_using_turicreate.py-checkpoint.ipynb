# %%
"""
Author: Eric Zair
File: linear_regression.py
Date 02/11/2020

DESCRIPTION: TBA
"""
# Out:
# '\nAuthor: Eric Zair\nFile: linear_regression.py\nDate 02/11/2020\n\nDESCRIPTION: TBA\n'

# %%
import turicreate

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
used_car_sales = turicreate.SFrame('../data/usedCar.csv')
# Out:
# Finished parsing file /home/ez/Workspace/Classes/Machine Learning/Assignment1/data/usedCar.csv
# Parsing completed. Parsed 100 lines in 0.147539 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,int,int,str,int,str,str,int,str,str,str,str,str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /home/ez/Workspace/Classes/Machine Learning/Assignment1/data/usedCar.csv
# Parsing completed. Parsed 17506 lines in 0.077131 secs.

# %%
used_car_sales.show()
# Out:
# Materializing SFrame
# <html>                 <body>                     <iframe style="border:0;margin:0" width="1000" height="4200" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 padding:5px;                                 background:#AAAAAA;                                 border-radius:4px;                                 padding-left:10px;                                 padding-right:10px;                                 margin-right:5px;                             }                             .vega-actions{                                 margin-top:20px;                                 text-align:center                             }                            .vega-actions > a{                                 background:#999999;                            }                             </style>                         </head>                         <body>                             <div id="vis">                             </div>                             <script>                                 var vega_json = "{\"marks\": [{\"type\": \"group\", \"encode\": {\"enter\": {\"clip\": {\"value\": 0}, \"x\": {\"value\": 0}, \"strokeWidth\": {\"value\": 0}, \"width\": {\"value\": 734}, \"stroke\": {\"value\": \"#000000\"}, \"fillOpacity\": {\"value\": 0}, \"height\": {\"value\": 366}, \"fill\": {\"value\": \"#ffffff\"}, \"y\": {\"value\": 0}}}, \"marks\": [{\"axes\": [], \"scales\": [], \"encode\": {\"enter\": {\"clip\": {\"value\": 0}, \"x\": {\"value\": 0}, \"strokeWidth\": {\"value\": 0}, \"width\": {\"value\": 734}, \"stroke\": {\"value\": \"#000000\"}, \"fillOpacity\": {\"value\": 0}, \"height\": {\"value\": 366}, \"fill\": {\"value\": \"#ffffff\"}, \"y\": {\"value\": 0}}}, \"marks\": [{\"type\": \"rect\", \"encode\": {\"update\": {\"x\": {\"signal\": \"datum[\\\"c_x_axis_back\\\"]\"}, \"y\": {\"field\": \"c_main_background\"}}, \"enter\": {\"strokeWidth\": {\"value\": 0.5}, \"stroke\": {\"value\": \"#DEDEDE\"}, \"fill\": {\"value\": \"#FEFEFE\"}, \"x\": {\"value\": 33}, \"width\": {\"value\": 700}, \"fillOpacity\": {\"value\": 1}, \"height\": {\"value\": 250}, \"y\": {\"value\": 66}}}, \"from\": {\"data\": \"data_2\"}}, {\"type\": \"rect\", \"encode\": {\"update\": {\"x\": {\"signal\": \"datum[\\\"c_x_axis_back\\\"]\"}, \"y\": {\"field\": \"c_top_bar\"}}, \"enter\": {\"strokeWidth\": {\"value\": 0.5}, \"stroke\": {\"value\": \"#DEDEDE\"}, \"fill\": {\"value\": \"#F5F5F5\"}, \"x\": {\"value\": 33}, \"width\": {\"value\": 700}, \"fillOpacity\": {\"value\": 1}, \"height\": {\"value\": 30}, \"y\": {\"value\": 43}}}, \"from\": {\"data\": \"data_2\"}}, {\"type\": \"text\", \"encode\": {\"update\": {\"x\": {\"signal\": \"datum[\\\"c_x_axis_back\\\"]+687\"}, \"y\": {\"field\": \"c_top_type\"}}, \"enter\": {\"fill\": {\"value\": \"#595859\"}, \"text\": {\"signal\": \"&apos;&apos;+datum[\\\"type\\\"]\"}, \"font\": {\"value\": \"AvenirNext-Medium\"}, \"dx\": {\"value\": 0, \"offset\": 0}, \"angle\": {\"value\": 0}, \"fontWeight\": {\"value\": \"normal\"}, \"fontSize\": {\"value\": 12}, \"fontStyle\": {\"value\": \"normal\"}, \"align\": {\"value\": \"right\"}, \"dy\": {\"value\": 0, \"offset\": 0}, \"x\": {\"value\": 720 ...

# %%
turicreate.show(used_car_sales[:5000]['mileage'], used_car_sales[:5000]['total.cost'])
# Out:
# Materializing X axis SArray
# Materializing Y axis SArray
# <html>                 <body>                     <iframe style="border:0;margin:0" width="920" height="770" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 padding:5px;                                 background:#AAAAAA;                                 border-radius:4px;                                 padding-left:10px;                                 padding-right:10px;                                 margin-right:5px;                             }                             .vega-actions{                                 margin-top:20px;                                 text-align:center                             }                            .vega-actions > a{                                 background:#999999;                            }                             </style>                         </head>                         <body>                             <div id="vis">                             </div>                             <script>                                 var vega_json = "{\"title\": \"X vs. Y\", \"data\": [{\"name\": \"source_2\", \"values\": [{\"x\": 67341, \"y\": 4037}, {\"x\": 69384, \"y\": 4662}, {\"x\": 58239, \"y\": 4459}, {\"x\": 58999, \"y\": 4279}, {\"x\": 47234, \"y\": 4472}, {\"x\": 64674, \"y\": 5256}, {\"x\": 92879, \"y\": 5522}, {\"x\": 67197, \"y\": 3194}, {\"x\": 98403, \"y\": 4332}, {\"x\": 87183, \"y\": 4249}, {\"x\": 58701, \"y\": 4834}, {\"x\": 72823, \"y\": 6886}, {\"x\": 93520, \"y\": 5537}, {\"x\": 79729, \"y\": 4520}, {\"x\": 91034, \"y\": 5583}, {\"x\": 72481, \"y\": 4146}, {\"x\": 51411, \"y\": 5083}, {\"x\": 71264, \"y\": 4402}, {\"x\": 98214, \"y\": 6794}, {\"x\": 69802, \"y\": 4964}, {\"x\": 96330, \"y\": 3924}, {\"x\": 85846, \"y\": 5203}, {\"x\": 69417, \"y\": 4241}, {\"x\": 63035, \"y\": 5510}, {\"x\": 65893, \"y\": 5921}, {\"x\": 63223, \"y\": 3165}, {\"x\": 71165, \"y\": 4026}, {\"x\": 102645, \"y\": 4031}, {\"x\": 77427, \"y\": 4569}, {\"x\": 103323, \"y\": 5590}, {\"x\": 46792, \"y\": 5768}, {\"x\": 76213, \"y\": 4824}, {\"x\": 89709, \"y\": 4095}, {\"x\": 25763, \"y\": 5500}, {\"x\": 92049, \"y\": 4302}, {\"x\": 88600, \"y\": 3196}, {\"x\": 81929, \"y\": 4977}, {\"x\": 65530, \"y\": 4391}, {\"x\": 75830, \"y\": 4570}, {\"x\": 66587, \"y\": 4889}, {\"x\": 93738, \"y\": 4970}, {\"x\": 86946, \"y\": 4447}, {\"x\": 93768, \"y\": 4431}, {\"x\": 106102, \"y\": 5558}, {\"x\": 74021, \"y\": 4218}, {\"x\": 100837, \"y\": 4601}, {\"x\": 109049, \"y\": 4321}, {\"x\": 58519, \"y\": 4636}, {\"x\": 107040, \"y\": 4817}, {\"x\": 76569, \"y\": 3539}, {\"x\": 72809, \"y\": 7063}, {\"x\": 80060, \"y\": 4402}, {\"x\": 72431, \"y\": 4349}, {\"x\": 84965, \"y\": 3558}, {\"x\": 56757, \"y\": 5060}, {\"x\": 72248, \"y\": 4710}, {\"x\": 63541, \"y\": 5260}, {\"x\": 89822, \"y\": 5620}, {\"x\": 75749, \"y\": 3882}, {\"x\": 76181, \"y\": 5580}, {\"x\": 99057, \"y\": 5080}, {\"x\": 100848, \"y\": 4291}, {\"x\": 78499, \"y\": 3991}, {\"x\": 96779, \"y\": 5193}, {\"x\": 57879, \"y\": 5577}, {\"x\": 82771, \"y\": 4370}, {\"x\": 76353, \"y\": 3891}, {\"x\": 80485, \"y\": 6101}, {\"x\": 70954, \"y\": 3157}, {\"x\": 57480, \"y\": 6430}, {\"x\": 74255, \"y\": 7578},  ...

# %%
# We want to make sure that we split our training and test data up to avoid overfitting.
training_data, test_data, = used_car_sales.random_split(.8, seed=0)

# %%
# Now, let's generate our model (using the built in turicreate methods).
mileage_model = turicreate.linear_regression.create(training_data, target='total.cost', features=['mileage'])
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 13360
# Number of features          : 1
# Number of unpacked features : 1
# Number of coefficients    : 2
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Validation Max Error | Training Root-Mean-Square Error | Validation Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | 1         | 2        | 0.003446     | 4962.790413        | 3329.646684          | 931.619558                      | 898.299847                        |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
# Alright, now hhwo good is our model?
# Let's check the numbers!
print(test_data['total.cost'].mean())
# Out:
# 4889.492446252181

# %%
print(mileage_model.evaluate(test_data))
# Out:
# {'max_error': 3907.67346301188, 'rmse': 918.1644518317131}

# %%
print(mileage_model.coefficients)
# Out:
# +-------------+-------+-----------------------+-----------------------+
# |     name    | index |         value         |         stderr        |
# +-------------+-------+-----------------------+-----------------------+
# | (intercept) |  None |   5423.813724913844   |   37.40898763734112   |
# |   mileage   |  None | -0.006816205457415535 | 0.0004747229410506382 |
# +-------------+-------+-----------------------+-----------------------+
# [2 rows x 4 columns]

# %%
# Create a line graph of our prediction on our test data, to see our results.
plt.plot(test_data['mileage'], test_data['total.cost'], '.',
         test_data['mileage'], mileage_model.predict(test_data), '-')
# Out:
# [<matplotlib.lines.Line2D at 0x7f484070b828>,
#  <matplotlib.lines.Line2D at 0x7f484070b9b0>]

# %%
# I like subarus, so i wanted to see what would result from doing the following:
subarus = used_car_sales[used_car_sales['make.model']=='SUBARU.IMPREZA']
                         
subarus.show()
# Out:
# Materializing SFrame
# <html>                 <body>                     <iframe style="border:0;margin:0" width="1000" height="4200" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 padding:5px;                                 background:#AAAAAA;                                 border-radius:4px;                                 padding-left:10px;                                 padding-right:10px;                                 margin-right:5px;                             }                             .vega-actions{                                 margin-top:20px;                                 text-align:center                             }                            .vega-actions > a{                                 background:#999999;                            }                             </style>                         </head>                         <body>                             <div id="vis">                             </div>                             <script>                                 var vega_json = "{\"marks\": [{\"type\": \"group\", \"encode\": {\"enter\": {\"clip\": {\"value\": 0}, \"x\": {\"value\": 0}, \"strokeWidth\": {\"value\": 0}, \"width\": {\"value\": 734}, \"stroke\": {\"value\": \"#000000\"}, \"fillOpacity\": {\"value\": 0}, \"height\": {\"value\": 366}, \"fill\": {\"value\": \"#ffffff\"}, \"y\": {\"value\": 0}}}, \"marks\": [{\"axes\": [], \"scales\": [], \"encode\": {\"enter\": {\"clip\": {\"value\": 0}, \"x\": {\"value\": 0}, \"strokeWidth\": {\"value\": 0}, \"width\": {\"value\": 734}, \"stroke\": {\"value\": \"#000000\"}, \"fillOpacity\": {\"value\": 0}, \"height\": {\"value\": 366}, \"fill\": {\"value\": \"#ffffff\"}, \"y\": {\"value\": 0}}}, \"marks\": [{\"type\": \"rect\", \"encode\": {\"update\": {\"x\": {\"signal\": \"datum[\\\"c_x_axis_back\\\"]\"}, \"y\": {\"field\": \"c_main_background\"}}, \"enter\": {\"strokeWidth\": {\"value\": 0.5}, \"stroke\": {\"value\": \"#DEDEDE\"}, \"fill\": {\"value\": \"#FEFEFE\"}, \"x\": {\"value\": 33}, \"width\": {\"value\": 700}, \"fillOpacity\": {\"value\": 1}, \"height\": {\"value\": 250}, \"y\": {\"value\": 66}}}, \"from\": {\"data\": \"data_2\"}}, {\"type\": \"rect\", \"encode\": {\"update\": {\"x\": {\"signal\": \"datum[\\\"c_x_axis_back\\\"]\"}, \"y\": {\"field\": \"c_top_bar\"}}, \"enter\": {\"strokeWidth\": {\"value\": 0.5}, \"stroke\": {\"value\": \"#DEDEDE\"}, \"fill\": {\"value\": \"#F5F5F5\"}, \"x\": {\"value\": 33}, \"width\": {\"value\": 700}, \"fillOpacity\": {\"value\": 1}, \"height\": {\"value\": 30}, \"y\": {\"value\": 43}}}, \"from\": {\"data\": \"data_2\"}}, {\"type\": \"text\", \"encode\": {\"update\": {\"x\": {\"signal\": \"datum[\\\"c_x_axis_back\\\"]+687\"}, \"y\": {\"field\": \"c_top_type\"}}, \"enter\": {\"fill\": {\"value\": \"#595859\"}, \"text\": {\"signal\": \"&apos;&apos;+datum[\\\"type\\\"]\"}, \"font\": {\"value\": \"AvenirNext-Medium\"}, \"dx\": {\"value\": 0, \"offset\": 0}, \"angle\": {\"value\": 0}, \"fontWeight\": {\"value\": \"normal\"}, \"fontSize\": {\"value\": 12}, \"fontStyle\": {\"value\": \"normal\"}, \"align\": {\"value\": \"right\"}, \"dy\": {\"value\": 0, \"offset\": 0}, \"x\": {\"value\": 720 ...

# %%
# I wonder what the predictions for subaru impreza's looks like. :)
print("For subaru imprezas:", mileage_model.predict(subarus))
# Out:
# For subaru imprezas: [4811.786636892503]
