# %% [markdown]
# # ID Block
#
# - Author: Eric Zair
# - File: turicreate_linear_regression.py.ipynb
# - Date 02/11/2020
#
# ## Program Description
#
# Using built in functions for this program I will create a linear regression model that will map the price of a given car to the expected value by only using mileage as a value. In otherwords, I will find the relation of milage to the price of a used car.

# %%
import turicreate

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
used_car_sales = turicreate.SFrame('../data/usedCar.csv')
# Out:
# Finished parsing file /home/ez/Workspace/Classes/Machine Learning/Assignment1/data/usedCar.csv
# Parsing completed. Parsed 100 lines in 0.237255 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,int,int,str,int,str,str,int,str,str,str,str,str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /home/ez/Workspace/Classes/Machine Learning/Assignment1/data/usedCar.csv
# Parsing completed. Parsed 17506 lines in 0.089006 secs.

# %% [markdown]
# ## Scatter Points Representing Mileage
#
# ### X = Mileage, Y = Total Cost of Car
#
# We want to fit a line for the below scatter points.

# %%
turicreate.show(used_car_sales[:5000]['mileage'], used_car_sales[:5000]['total.cost'])
# Out:
# Materializing X axis SArray
# Materializing Y axis SArray
# <html>                 <body>                     <iframe style="border:0;margin:0" width="920" height="770" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 padding:5px;                                 background:#AAAAAA;                                 border-radius:4px;                                 padding-left:10px;                                 padding-right:10px;                                 margin-right:5px;                             }                             .vega-actions{                                 margin-top:20px;                                 text-align:center                             }                            .vega-actions > a{                                 background:#999999;                            }                             </style>                         </head>                         <body>                             <div id="vis">                             </div>                             <script>                                 var vega_json = "{\"height\": 550, \"marks\": [{\"style\": [\"circle\"], \"type\": \"symbol\", \"encode\": {\"update\": {\"fill\": {\"value\": \"#108EE9\"}, \"shape\": {\"value\": \"circle\"}, \"x\": {\"scale\": \"x\", \"field\": \"x\"}, \"y\": {\"scale\": \"y\", \"field\": \"y\", \"title\": \"Miles per Gallon\"}, \"opacity\": {\"value\": 0.7}}, \"hover\": {\"fill\": {\"value\": \"#7EC2F3\"}}}, \"from\": {\"data\": \"source_2\"}, \"name\": \"marks\"}], \"title\": \"X vs. Y\", \"width\": 720, \"style\": \"cell\", \"autosize\": {\"resize\": false, \"contains\": \"padding\", \"type\": \"fit\"}, \"padding\": 8, \"axes\": [{\"orient\": \"bottom\", \"title\": \"X\", \"scale\": \"x\", \"zindex\": 1, \"tickCount\": {\"signal\": \"ceil(width/40)\"}, \"labelOverlap\": true}, {\"domain\": false, \"labels\": false, \"grid\": true, \"orient\": \"bottom\", \"scale\": \"x\", \"gridScale\": \"y\", \"zindex\": 0, \"maxExtent\": 0, \"tickCount\": {\"signal\": \"ceil(width/40)\"}, \"minExtent\": 0, \"ticks\": false}, {\"orient\": \"left\", \"title\": \"Y\", \"scale\": \"y\", \"zindex\": 1, \"tickCount\": {\"signal\": \"ceil(height/40)\"}, \"labelOverlap\": true}, {\"domain\": false, \"labels\": false, \"grid\": true, \"orient\": \"left\", \"scale\": \"y\", \"gridScale\": \"x\", \"zindex\": 0, \"maxExtent\": 0, \"tickCount\": {\"signal\": \"ceil(height/40)\"}, \"minExtent\": 0, \"ticks\": false}], \"$schema\": \"https://vega.github.io/schema/vega/v4.json\", \"data\": [{\"values\": [{\"x\": 67341, \"y\": 4037}, {\"x\": 69384, \"y\": 4662}, {\"x\": 58239, \"y\": 4459}, {\"x\": 58999, \"y\": 4279}, {\"x\": 47234, \"y\": 4472}, {\"x\": 64674, \"y\": 5256}, {\"x\": 92879, \"y\": 5522}, {\"x\": 67197, \"y\": 3194}, {\"x\": 98403, \"y\": 4332}, {\"x\": 87183, \"y\": 4249}, {\"x\": 58701, \"y\": 4834}, {\"x\": 72823, \"y\": 6886}, {\"x\": 93520, \"y\": 5537}, {\"x\": 79729, \"y\": 4520}, {\"x\": 91034, \"y\": 5583}, {\"x\": 72481, \"y\": 4146}, {\"x\": 51411, \"y\": 5083}, {\"x\": 71264, \"y\": 4402}, {\"x\": 98214, \"y\": 6794}, {\"x\": 69802, \"y\": 4964}, {\"x\": 96330, \"y\": 3924}, {\"x\": 85846, \"y\": 5203}, {\"x\": 69417, \"y\": 4241}, {\" ...

# %%
used_car_sales.show()
# Out:
# Materializing SFrame
# <html>                 <body>                     <iframe style="border:0;margin:0" width="1000" height="4200" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 padding:5px;                                 background:#AAAAAA;                                 border-radius:4px;                                 padding-left:10px;                                 padding-right:10px;                                 margin-right:5px;                             }                             .vega-actions{                                 margin-top:20px;                                 text-align:center                             }                            .vega-actions > a{                                 background:#999999;                            }                             </style>                         </head>                         <body>                             <div id="vis">                             </div>                             <script>                                 var vega_json = "{\"height\": 3980, \"marks\": [{\"marks\": [{\"marks\": [{\"encode\": {\"update\": {\"x\": {\"signal\": \"datum[\\\"c_x_axis_back\\\"]\"}, \"y\": {\"field\": \"c_main_background\"}}, \"enter\": {\"fill\": {\"value\": \"#FEFEFE\"}, \"x\": {\"value\": 33}, \"height\": {\"value\": 250}, \"stroke\": {\"value\": \"#DEDEDE\"}, \"width\": {\"value\": 700}, \"strokeWidth\": {\"value\": 0.5}, \"fillOpacity\": {\"value\": 1}, \"y\": {\"value\": 66}}}, \"from\": {\"data\": \"data_2\"}, \"type\": \"rect\"}, {\"encode\": {\"update\": {\"x\": {\"signal\": \"datum[\\\"c_x_axis_back\\\"]\"}, \"y\": {\"field\": \"c_top_bar\"}}, \"enter\": {\"fill\": {\"value\": \"#F5F5F5\"}, \"x\": {\"value\": 33}, \"height\": {\"value\": 30}, \"stroke\": {\"value\": \"#DEDEDE\"}, \"width\": {\"value\": 700}, \"strokeWidth\": {\"value\": 0.5}, \"fillOpacity\": {\"value\": 1}, \"y\": {\"value\": 43}}}, \"from\": {\"data\": \"data_2\"}, \"type\": \"rect\"}, {\"encode\": {\"update\": {\"x\": {\"signal\": \"datum[\\\"c_x_axis_back\\\"]+687\"}, \"y\": {\"field\": \"c_top_type\"}}, \"enter\": {\"baseline\": {\"value\": \"middle\"}, \"fontWeight\": {\"value\": \"normal\"}, \"x\": {\"value\": 720}, \"fontSize\": {\"value\": 12}, \"fill\": {\"value\": \"#595859\"}, \"dx\": {\"offset\": 0, \"value\": 0}, \"fontStyle\": {\"value\": \"normal\"}, \"font\": {\"value\": \"AvenirNext-Medium\"}, \"align\": {\"value\": \"right\"}, \"angle\": {\"value\": 0}, \"y\": {\"value\": 58}, \"text\": {\"signal\": \"&apos;&apos;+datum[\\\"type\\\"]\"}, \"dy\": {\"offset\": 0, \"value\": 0}}}, \"from\": {\"data\": \"data_2\"}, \"type\": \"text\"}, {\"encode\": {\"update\": {\"x\": {\"signal\": \"datum[\\\"c_x_axis_back\\\"]+11\"}, \"y\": {\"field\": \"c_top_title\"}}, \"enter\": {\"baseline\": {\"value\": \"middle\"}, \"fontWeight\": {\"value\": \"normal\"}, \"x\": {\"value\": 44}, \"fontSize\": {\"value\": 15}, \"fill\": {\"value\": \"#9B9B9B\"}, \"dx\": {\"offset\": 0, \"value\": 0}, \"fontStyle\": {\"value\": \"normal\"}, \"font\": {\"value\": \"AvenirNext-Medium\"}, \"align\": {\"value\": \"left\"}, \"angle\": {\"value\": 0}, \"y\": {\"value\": 59}, \"text\":  ...

# %% [markdown]
# ## Split The Training & Test Data
#
# ### 80% Training Data, 20% Testing Data

# %%
training_data, test_data, = used_car_sales.random_split(.8, seed=0)

# %% [markdown]
# ## Now, let's generate our model (using the built in turicreate methods).

# %%
mileage_model = turicreate.linear_regression.create(training_data, target='total.cost', features=['mileage'])
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 13360
# Number of features          : 1
# Number of unpacked features : 1
# Number of coefficients    : 2
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Validation Max Error | Training Root-Mean-Square Error | Validation Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | 1         | 2        | 1.007635     | 4959.434775        | 4965.736923          | 930.825598                      | 913.749233                        |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %% [markdown]
# ## Mean total cost of test data

# %%
print(test_data['total.cost'].mean())
# Out:
# 4889.492446252181

# %% [markdown]
# ## Our RMSE & Maximum error after

# %%
print(mileage_model.evaluate(test_data))
# Out:
# {'rmse': 918.1469201270459, 'max_error': 3909.7288524538135}

# %% [markdown]
# ## Coefficients

# %%
print(mileage_model.coefficients)
# Out:
# +-------------+-------+-----------------------+-----------------------+
# |     name    | index |         value         |         stderr        |
# +-------------+-------+-----------------------+-----------------------+
# | (intercept) |  None |   5429.513647001827   |   37.26444936424798   |
# |   mileage   |  None | -0.006918952033063598 | 0.0004725287712555266 |
# +-------------+-------+-----------------------+-----------------------+
# [2 rows x 4 columns]

# %% [markdown]
# ## Linear Line After Evaluating

# %%
# Create a line graph of our prediction on our test data, to see our results.
plt.plot(test_data['mileage'], test_data['total.cost'], '.',
         test_data['mileage'], mileage_model.predict(test_data), '-')
# Out:
# [<matplotlib.lines.Line2D at 0x7f6060ca5748>,
#  <matplotlib.lines.Line2D at 0x7f6060ca58d0>]

# %% [markdown]
# ## I just like subarus, so I was messing around

# %%
# I like subarus, so i wanted to see what would result from doing the following:
subarus = used_car_sales[used_car_sales['make.model']=='SUBARU.IMPREZA']
                         
subarus.show()
# Out:
# Materializing SFrame
# <html>                 <body>                     <iframe style="border:0;margin:0" width="1000" height="4200" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 padding:5px;                                 background:#AAAAAA;                                 border-radius:4px;                                 padding-left:10px;                                 padding-right:10px;                                 margin-right:5px;                             }                             .vega-actions{                                 margin-top:20px;                                 text-align:center                             }                            .vega-actions > a{                                 background:#999999;                            }                             </style>                         </head>                         <body>                             <div id="vis">                             </div>                             <script>                                 var vega_json = "{\"height\": 3980, \"marks\": [{\"marks\": [{\"marks\": [{\"encode\": {\"update\": {\"x\": {\"signal\": \"datum[\\\"c_x_axis_back\\\"]\"}, \"y\": {\"field\": \"c_main_background\"}}, \"enter\": {\"fill\": {\"value\": \"#FEFEFE\"}, \"x\": {\"value\": 33}, \"height\": {\"value\": 250}, \"stroke\": {\"value\": \"#DEDEDE\"}, \"width\": {\"value\": 700}, \"strokeWidth\": {\"value\": 0.5}, \"fillOpacity\": {\"value\": 1}, \"y\": {\"value\": 66}}}, \"from\": {\"data\": \"data_2\"}, \"type\": \"rect\"}, {\"encode\": {\"update\": {\"x\": {\"signal\": \"datum[\\\"c_x_axis_back\\\"]\"}, \"y\": {\"field\": \"c_top_bar\"}}, \"enter\": {\"fill\": {\"value\": \"#F5F5F5\"}, \"x\": {\"value\": 33}, \"height\": {\"value\": 30}, \"stroke\": {\"value\": \"#DEDEDE\"}, \"width\": {\"value\": 700}, \"strokeWidth\": {\"value\": 0.5}, \"fillOpacity\": {\"value\": 1}, \"y\": {\"value\": 43}}}, \"from\": {\"data\": \"data_2\"}, \"type\": \"rect\"}, {\"encode\": {\"update\": {\"x\": {\"signal\": \"datum[\\\"c_x_axis_back\\\"]+687\"}, \"y\": {\"field\": \"c_top_type\"}}, \"enter\": {\"baseline\": {\"value\": \"middle\"}, \"fontWeight\": {\"value\": \"normal\"}, \"x\": {\"value\": 720}, \"fontSize\": {\"value\": 12}, \"fill\": {\"value\": \"#595859\"}, \"dx\": {\"offset\": 0, \"value\": 0}, \"fontStyle\": {\"value\": \"normal\"}, \"font\": {\"value\": \"AvenirNext-Medium\"}, \"align\": {\"value\": \"right\"}, \"angle\": {\"value\": 0}, \"y\": {\"value\": 58}, \"text\": {\"signal\": \"&apos;&apos;+datum[\\\"type\\\"]\"}, \"dy\": {\"offset\": 0, \"value\": 0}}}, \"from\": {\"data\": \"data_2\"}, \"type\": \"text\"}, {\"encode\": {\"update\": {\"x\": {\"signal\": \"datum[\\\"c_x_axis_back\\\"]+11\"}, \"y\": {\"field\": \"c_top_title\"}}, \"enter\": {\"baseline\": {\"value\": \"middle\"}, \"fontWeight\": {\"value\": \"normal\"}, \"x\": {\"value\": 44}, \"fontSize\": {\"value\": 15}, \"fill\": {\"value\": \"#9B9B9B\"}, \"dx\": {\"offset\": 0, \"value\": 0}, \"fontStyle\": {\"value\": \"normal\"}, \"font\": {\"value\": \"AvenirNext-Medium\"}, \"align\": {\"value\": \"left\"}, \"angle\": {\"value\": 0}, \"y\": {\"value\": 59}, \"text\":  ...

# %%
# I wonder what the predictions for subaru impreza's looks like. :)
print("For subaru imprezas:", mileage_model.predict(subarus))
# Out:
# For subaru imprezas: [4808.260943953046]
